# %% [markdown]
# # Section 3 Classifier

# %% [markdown]
# In this section, we employed three classifier models:
# (1)Logistic Regression
# (2) Random Forest
# (3) XGBoost
# Logistic Regression serves as a baseline model, Random Forest provides strong performance with built-in feature selection, and XGBoost offers a powerful boosting approach that in comparision with random forest.

# %%
import pandas as pd

df = pd.read_csv("../data/preprocessed/cleaned_raw_encoded.csv")
df.head()
# Out:
#    age  class of worker  detailed industry recode  detailed occupation recode  \
# 0   73              3.0                         0                           0
# 1   58              6.0                         4                          34
# 2   18              3.0                         0                           0
# 3    9              3.0                         0                           0
# 4   10              3.0                         0                           0
#
#    education  wage per hour  enroll in edu inst last wk  marital stat  \
# 0       12.0              0                         2.0           6.0
# 1       16.0              0                         2.0           0.0
# 2        0.0              0                         1.0           4.0
# 3       10.0              0                         2.0           4.0
# 4       10.0              0                         2.0           4.0
#
#    major industry code  major occupation code  ...  country of birth father  \
# 0                 14.0                    6.0  ...                     39.0
# 1                  4.0                    8.0  ...                     39.0
# 2                 14.0                    6.0  ...                     41.0
# 3                 14.0                    6.0  ...                     39.0
# 4                 14.0                    6.0  ...                     39.0
#
#    country of birth mother  country of birth self  citizenship  \
# 0                     39.0                   39.0          4.0
# 1                     39.0                   39.0          4.0
# 2                     41.0                   41.0          0.0
# 3                     39.0                   39.0          4.0
# 4                     39.0                   39.0          4.0
#
#    own business or self employed  fill inc questionnaire for veteran's admin  \
# 0                              0                                         1.0
# 1                              0                                         1.0
# 2                              0                                         1.0
# 3                              0                                         1.0
# 4                              0                                         1.0
#
#    veterans benefits  weeks worked in year  year  label
# 0                  2                     0    95      0
# 1                  2                    52    94      0
# 2                  2                     0    95      0
# 3                  0                     0    94      0
# 4                  0                     0    94      0
#
# [5 rows x 42 columns]

# %%
## drop the Label and weight for feature data X
X = df.drop(columns=["label"])
y = df["label"]     # 0 = <50K, 1 = >50K
w = df["weight"]

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
# Scale ONLY for logistic regression
scaler = StandardScaler()
encoder = OrdinalEncoder()

# Identify types
categorical_cols = df.select_dtypes(include="object").columns.tolist()


numeric_cols = [
    'age', 'wage per hour', 'capital gains', 'capital losses',
    'dividends from stocks', 'weight', 'num persons worked for employer',
    'own business or self employed', 'veterans benefits',
    'weeks worked in year', 'year'
]
X[categorical_cols] = encoder.fit_transform(X[categorical_cols])

# Scale numeric columns
scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])


## conduct the train test split and scale the data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(
    X, y, w,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ### Logistic regression

# %% [markdown]
# train and predict using the logistic regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score


log_clf = LogisticRegression(max_iter=500)
log_clf.fit(X_train, y_train, sample_weight=w_train)
y_pred = log_clf.predict(X_test)
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test, y_pred, sample_weight=w_test)
acc
# Out:
# /opt/anaconda3/envs/jpm_project_chuanye/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9461917997765783

# %% [markdown]
# ### Random Forest
# train and predict using the random forrest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, confusion_matrix
)
import seaborn as sns
import matplotlib.pyplot as plt

# Build the model
rf = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    n_jobs=-1
)

# Train (IMPORTANT: include sample_weight)
rf.fit(X_train, y_train, sample_weight=w_train)

# Predictions
y_pred_rf = rf.predict(X_test)
y_proba_rf = rf.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Run the Feature ranking by the random forest

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Save feature names BEFORE scaling
feature_names = X_train.columns

# After RandomForest training
importances = rf.feature_importances_

# Create DataFrame with names + importance
importance_df = pd.DataFrame({
    "feature": feature_names,
    "importance": importances
}).sort_values(by="importance", ascending=False)

importance_df.head(40)
# Out:
#                                        feature  importance
# 24                                      weight    0.097009
# 3                   detailed occupation recode    0.091985
# 0                                          age    0.089934
# 18                       dividends from stocks    0.088754
# 16                               capital gains    0.083450
# 2                     detailed industry recode    0.053279
# 4                                    education    0.050533
# 30             num persons worked for employer    0.040114
# 39                        weeks worked in year    0.038072
# 8                          major industry code    0.036633
# 12                                         sex    0.033215
# 9                        major occupation code    0.031354
# 17                              capital losses    0.026584
# 1                              class of worker    0.023458
# 19                              tax filer stat    0.017708
# 22          detailed household and family stat    0.017369
# 7                                 marital stat    0.016135
# 32                     country of birth father    0.013692
# 33                     country of birth mother    0.012984
# 36               own business or self employed    0.012506
# 23     detailed household summary in household    0.012382
# 13                     member of a labor union    0.012110
# 5                                wage per hour    0.011670
# 15           full or part time employment stat    0.010822
# 10                                        race    0.008793
# 34                       country of birth self    0.007617
# 26                migration code-change in reg    0.006670
# 27              migration code-move within reg    0.006569
# 25                migration code-change in msa    0.006330
# 29               migration prev res in sunbelt    0.006158
# 28               live in this house 1 year ago    0.005841
# 11                             hispanic origin    0.005755
# 35                                 citizenship    0.005410
# 21                 state of previous residence    0.004591
# 40                                        year    0.004241
# 20                region of previous residence    0.003090
# 14                     reason for unemployment    0.002142
# 37  fill inc questionnaire for veteran's admin    0.001927
# 38                           veterans benefits    0.001886
# 31                     family members under 18    0.000683

# %% [markdown]
# ### XGBoost
# train and predict using the random forrest

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="logloss"
)
xgb_clf.fit(X_train, y_train, sample_weight=w_train)

y_pred = xgb_clf.predict(X_test)
y_proba = xgb_clf.predict_proba(X_test)[:, 1]
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# For the Model Evaluation code, please see the src/evaluation.py
